# %%
# %matplotlib inline
from helpers import *
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import rotate

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Loaded a set of images
n = 20

imgs, gt_imgs = load_images(n)

imgs[0].shape, gt_imgs[0].shape
# Out:
# Loading 20 images
# ((400, 400, 3), (400, 400))

# %%
# apply some transformation
mirror = True
rotation = 0
imgs_aug = augment_images(imgs, mirror=True, degrees=45)

# %%
# show transformation on an image
i = 1

fig, axes = plt.subplots(1,2)
fig.set_size_inches((20, 10))

axes[0].imshow(imgs[i], cmap='Greys_r')
axes[1].imshow(imgs_aug[i], cmap='Greys_r')

# just check the ratio of black pixels
mask = np.all(imgs_aug[i]==3, axis=2) # check where all of the three colors are set to 0s
npixels = imgs_aug[i].shape[0]*imgs_aug[i].shape[1]
print("Ratio of \"out\" pixels in the obtained image:", np.sum(mask), "/", npixels, "=", np.sum(mask)/npixels)
# Out:
# Ratio of "out" pixels in the obtained image: 160744 / 320356 = 0.501766784452
